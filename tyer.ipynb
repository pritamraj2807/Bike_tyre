# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import os

# %%
img=image.load_img("/content/drive/MyDrive/BASE_DATA_mul/Training/bad/s (264).jpg")
plt.imshow(img)

# %%
img=image.load_img("/content/drive/MyDrive/BASE_DATA_mul/Training/good/z (264).jpg")
plt.imshow(img)

# %%
import glob
x_train = glob.glob('/content/drive/MyDrive/BASE_DATA_mul/Training/bad/*.*')
y_train = glob.glob('/content/drive/MyDrive/BASE_DATA_mul/Training/good/*.*')

# %%
data = []
labels = []

for i in x_train:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(0)

# %%
for i in y_train:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(1)

# %%
len(data)
# Out:
# 612

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, ytrain, ytest = train_test_split(data, labels, test_size=0.2,random_state=70)

# %%
len(X_train)
# Out:
# 489

# %%
X_train = np.array(X_train, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)
ytrain = np.array(ytrain, dtype=np.float32)
ytest = np.array(ytest, dtype=np.float32)

# %%
print(ytrain.shape)
# Out:
# (489,)

# %%
print(len(X_train))
print(len(ytrain))
print(len(X_test))
print(len(ytest))

print(X_train.shape)
print(ytrain.shape)
print(X_test.shape)
print(ytest.shape)
# Out:
# 489
# 489
# 123
# 123
# (489, 280, 280, 3)
# (489,)
# (123, 280, 280, 3)
# (123,)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
from keras.utils import np_utils
ytrain = np_utils.to_categorical(ytrain)
ytest = np_utils.to_categorical(ytest)
num_classes = ytest.shape[1]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import RMSprop
from keras.layers.convolutional import Conv2D
from keras.layers import BatchNormalization
from keras.layers.convolutional import MaxPooling2D
from sklearn.model_selection import train_test_split

# %%
def AlexNet_model():

    model = Sequential()
    
    model.add(Conv2D(32, (3, 3), input_shape=(280, 280, 3), activation='relu',padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    
    model.add(Conv2D(32, (3, 3), activation='relu',padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), activation='relu',padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    
    model.add(Conv2D(128, (3, 3), activation='relu',padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(128, (3, 3), activation='relu',padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Dropout(0.5))
    model.add(Flatten())
    
    model.add(Dense(1024, activation='relu'))
    model.add(Dense(512, activation='relu'))
    
    model.add(Dense(num_classes, activation='softmax'))
    
    lrate = 0.01
    epochs=25
    decay = lrate/epochs
    sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
    
    return model

# %%
model = AlexNet_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 280, 280, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 140, 140, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 140, 140, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 70, 70, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 70, 70, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 35, 35, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 35, 35, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 17, 17, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 8, 8, 128)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1024)              8389632
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 9,165,538
# Trainable params: 9,165,538
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
os.chdir("/content/drive/My Drive/2021/")
from keras.callbacks import ModelCheckpoint, CSVLogger
mc = ModelCheckpoint('TyreAlexNetNet.h5', monitor='val_loss', save_best_only=True)
cv = CSVLogger('TyreAlexNetNet.csv',append=True)

# %%
history=model.fit(np.array(X_train), np.array(ytrain), validation_split=(0.2), epochs=80, batch_size=32,verbose=2,callbacks=[cv,mc])
# Out:
# Epoch 1/80
# 13/13 - 14s - loss: 0.6937 - accuracy: 0.4962 - val_loss: 0.6893 - val_accuracy: 0.5306 - 14s/epoch - 1s/step
# Epoch 2/80
# 13/13 - 1s - loss: 0.6914 - accuracy: 0.5141 - val_loss: 0.6866 - val_accuracy: 0.5306 - 1s/epoch - 93ms/step
# Epoch 3/80
# 13/13 - 1s - loss: 0.6890 - accuracy: 0.5166 - val_loss: 0.6836 - val_accuracy: 0.5306 - 1s/epoch - 95ms/step
# Epoch 4/80
# 13/13 - 1s - loss: 0.6904 - accuracy: 0.5115 - val_loss: 0.6860 - val_accuracy: 0.6327 - 950ms/epoch - 73ms/step
# Epoch 5/80
# 13/13 - 1s - loss: 0.6839 - accuracy: 0.5371 - val_loss: 0.6819 - val_accuracy: 0.5306 - 1s/epoch - 93ms/step
# Epoch 6/80
# 13/13 - 1s - loss: 0.6820 - accuracy: 0.5729 - val_loss: 0.6727 - val_accuracy: 0.6429 - 1s/epoch - 94ms/step
# Epoch 7/80
# 13/13 - 1s - loss: 0.6877 - accuracy: 0.5371 - val_loss: 0.6758 - val_accuracy: 0.5918 - 952ms/epoch - 73ms/step
# Epoch 8/80
# 13/13 - 1s - loss: 0.6722 - accuracy: 0.6138 - val_loss: 0.6592 - val_accuracy: 0.6531 - 1s/epoch - 90ms/step
# Epoch 9/80
# 13/13 - 1s - loss: 0.6692 - accuracy: 0.6061 - val_loss: 0.6436 - val_accuracy: 0.6429 - 1s/epoch - 96ms/step
# Epoch 10/80
# 13/13 - 1s - loss: 0.6763 - accuracy: 0.5499 - val_loss: 0.6158 - val_accuracy: 0.6735 - 1s/epoch - 90ms/step
# Epoch 11/80
# 13/13 - 1s - loss: 0.6282 - accuracy: 0.6854 - val_loss: 0.5869 - val_accuracy: 0.6735 - 1s/epoch - 97ms/step
# Epoch 12/80
# 13/13 - 1s - loss: 0.6421 - accuracy: 0.6419 - val_loss: 0.6991 - val_accuracy: 0.4694 - 1s/epoch - 78ms/step
# Epoch 13/80
# 13/13 - 1s - loss: 0.6826 - accuracy: 0.5806 - val_loss: 0.6758 - val_accuracy: 0.5612 - 1s/epoch - 81ms/step
# Epoch 14/80
# 13/13 - 1s - loss: 0.6711 - accuracy: 0.5729 - val_loss: 0.6372 - val_accuracy: 0.6224 - 934ms/epoch - 72ms/step
# Epoch 15/80
# 13/13 - 1s - loss: 0.6357 - accuracy: 0.6445 - val_loss: 0.6367 - val_accuracy: 0.6020 - 957ms/epoch - 74ms/step
# Epoch 16/80
# 13/13 - 1s - loss: 0.6180 - accuracy: 0.6419 - val_loss: 0.6317 - val_accuracy: 0.6122 - 976ms/epoch - 75ms/step
# Epoch 17/80
# 13/13 - 1s - loss: 0.5936 - accuracy: 0.6829 - val_loss: 0.6131 - val_accuracy: 0.7653 - 964ms/epoch - 74ms/step
# Epoch 18/80
# 13/13 - 1s - loss: 0.6195 - accuracy: 0.6522 - val_loss: 0.6452 - val_accuracy: 0.6429 - 949ms/epoch - 73ms/step
# Epoch 19/80
# 13/13 - 1s - loss: 0.6197 - accuracy: 0.7084 - val_loss: 0.5874 - val_accuracy: 0.7041 - 982ms/epoch - 76ms/step
# Epoch 20/80
# 13/13 - 2s - loss: 0.5899 - accuracy: 0.7084 - val_loss: 0.5531 - val_accuracy: 0.7449 - 2s/epoch - 137ms/step
# Epoch 21/80
# 13/13 - 1s - loss: 0.5466 - accuracy: 0.7212 - val_loss: 0.6345 - val_accuracy: 0.5816 - 1s/epoch - 79ms/step
# Epoch 22/80
# 13/13 - 1s - loss: 0.5631 - accuracy: 0.7238 - val_loss: 0.5817 - val_accuracy: 0.7143 - 984ms/epoch - 76ms/step
# Epoch 23/80
# 13/13 - 1s - loss: 0.5075 - accuracy: 0.7647 - val_loss: 0.5603 - val_accuracy: 0.7449 - 960ms/epoch - 74ms/step
# Epoch 24/80
# 13/13 - 1s - loss: 0.5007 - accuracy: 0.7570 - val_loss: 0.5917 - val_accuracy: 0.7755 - 1s/epoch - 79ms/step
# Epoch 25/80
# 13/13 - 1s - loss: 0.4974 - accuracy: 0.8005 - val_loss: 0.5475 - val_accuracy: 0.7449 - 1s/epoch - 111ms/step
# Epoch 26/80
# 13/13 - 1s - loss: 0.4970 - accuracy: 0.7519 - val_loss: 0.5231 - val_accuracy: 0.7551 - 1s/epoch - 97ms/step
# Epoch 27/80
# 13/13 - 1s - loss: 0.4513 - accuracy: 0.8414 - val_loss: 0.5279 - val_accuracy: 0.7755 - 947ms/epoch - 73ms/step
# Epoch 28/80
# 13/13 - 1s - loss: 0.4467 - accuracy: 0.8133 - val_loss: 0.5626 - val_accuracy: 0.7551 - 947ms/epoch - 73ms/step
# Epoch 29/80
# 13/13 - 1s - loss: 0.4169 - accuracy: 0.8210 - val_loss: 0.6191 - val_accuracy: 0.7041 - 944ms/epoch - 73ms/step
# Epoch 30/80
# 13/13 - 1s - loss: 0.4996 - accuracy: 0.7749 - val_loss: 0.5302 - val_accuracy: 0.7347 - 944ms/epoch - 73ms/step
# Epoch 31/80
# 13/13 - 1s - loss: 0.4018 - accuracy: 0.8363 - val_loss: 0.4804 - val_accuracy: 0.7959 - 1s/epoch - 90ms/step
# Epoch 32/80
# 13/13 - 1s - loss: 0.3783 - accuracy: 0.8363 - val_loss: 0.4460 - val_accuracy: 0.8367 - 1s/epoch - 91ms/step
# Epoch 33/80
# 13/13 - 1s - loss: 0.4343 - accuracy: 0.8235 - val_loss: 0.4587 - val_accuracy: 0.8265 - 1s/epoch - 77ms/step
# Epoch 34/80
# 13/13 - 1s - loss: 0.3404 - accuracy: 0.8645 - val_loss: 0.5567 - val_accuracy: 0.7041 - 955ms/epoch - 73ms/step
# Epoch 35/80
# 13/13 - 1s - loss: 0.4316 - accuracy: 0.8082 - val_loss: 0.5363 - val_accuracy: 0.7653 - 950ms/epoch - 73ms/step
# Epoch 36/80
# 13/13 - 1s - loss: 0.4224 - accuracy: 0.8465 - val_loss: 0.4833 - val_accuracy: 0.8061 - 941ms/epoch - 72ms/step
# Epoch 37/80
# 13/13 - 1s - loss: 0.3484 - accuracy: 0.8414 - val_loss: 0.4411 - val_accuracy: 0.7755 - 1s/epoch - 90ms/step
# Epoch 38/80
# 13/13 - 1s - loss: 0.2889 - accuracy: 0.8542 - val_loss: 0.4466 - val_accuracy: 0.8367 - 968ms/epoch - 74ms/step
# Epoch 39/80
# 13/13 - 1s - loss: 0.2662 - accuracy: 0.8798 - val_loss: 0.3969 - val_accuracy: 0.8673 - 1s/epoch - 90ms/step
# Epoch 40/80
# 13/13 - 1s - loss: 0.2392 - accuracy: 0.9207 - val_loss: 0.7023 - val_accuracy: 0.7653 - 942ms/epoch - 72ms/step
# Epoch 41/80
# 13/13 - 1s - loss: 0.3216 - accuracy: 0.8619 - val_loss: 0.3965 - val_accuracy: 0.8571 - 1s/epoch - 90ms/step
# Epoch 42/80
# 13/13 - 1s - loss: 0.2395 - accuracy: 0.9079 - val_loss: 0.4049 - val_accuracy: 0.8776 - 955ms/epoch - 73ms/step
# Epoch 43/80
# 13/13 - 1s - loss: 0.2000 - accuracy: 0.9284 - val_loss: 0.3745 - val_accuracy: 0.8878 - 1s/epoch - 89ms/step
# Epoch 44/80
# 13/13 - 1s - loss: 0.1294 - accuracy: 0.9668 - val_loss: 0.5119 - val_accuracy: 0.8469 - 978ms/epoch - 75ms/step
# Epoch 45/80
# 13/13 - 1s - loss: 0.1546 - accuracy: 0.9335 - val_loss: 0.4061 - val_accuracy: 0.8673 - 951ms/epoch - 73ms/step
# Epoch 46/80
# 13/13 - 1s - loss: 0.1045 - accuracy: 0.9616 - val_loss: 0.4633 - val_accuracy: 0.8571 - 952ms/epoch - 73ms/step
# Epoch 47/80
# 13/13 - 1s - loss: 0.0863 - accuracy: 0.9693 - val_loss: 0.6917 - val_accuracy: 0.8469 - 961ms/epoch - 74ms/step
# Epoch 48/80
# 13/13 - 1s - loss: 0.1297 - accuracy: 0.9463 - val_loss: 0.4326 - val_accuracy: 0.8673 - 945ms/epoch - 73ms/step
# Epoch 49/80
# 13/13 - 1s - loss: 0.0930 - accuracy: 0.9668 - val_loss: 0.4442 - val_accuracy: 0.8878 - 962ms/epoch - 74ms/step
# Epoch 50/80
# 13/13 - 1s - loss: 0.0709 - accuracy: 0.9744 - val_loss: 0.5043 - val_accuracy: 0.8980 - 960ms/epoch - 74ms/step
# Epoch 51/80
# 13/13 - 1s - loss: 0.0990 - accuracy: 0.9591 - val_loss: 0.4531 - val_accuracy: 0.8776 - 996ms/epoch - 77ms/step
# Epoch 52/80
# 13/13 - 1s - loss: 0.0984 - accuracy: 0.9616 - val_loss: 0.3740 - val_accuracy: 0.8571 - 1s/epoch - 91ms/step
# Epoch 53/80
# 13/13 - 1s - loss: 0.0758 - accuracy: 0.9591 - val_loss: 0.5863 - val_accuracy: 0.8469 - 950ms/epoch - 73ms/step
# Epoch 54/80
# 13/13 - 1s - loss: 0.0501 - accuracy: 0.9795 - val_loss: 0.5880 - val_accuracy: 0.8980 - 963ms/epoch - 74ms/step
# Epoch 55/80
# 13/13 - 1s - loss: 0.0691 - accuracy: 0.9744 - val_loss: 0.4962 - val_accuracy: 0.8776 - 956ms/epoch - 74ms/step
# Epoch 56/80
# 13/13 - 1s - loss: 0.0962 - accuracy: 0.9616 - val_loss: 0.5192 - val_accuracy: 0.8980 - 952ms/epoch - 73ms/step
# Epoch 57/80
# 13/13 - 1s - loss: 0.0816 - accuracy: 0.9642 - val_loss: 0.4580 - val_accuracy: 0.8980 - 962ms/epoch - 74ms/step
# Epoch 58/80
# 13/13 - 1s - loss: 0.0439 - accuracy: 0.9872 - val_loss: 0.6516 - val_accuracy: 0.8878 - 952ms/epoch - 73ms/step
# Epoch 59/80
# 13/13 - 1s - loss: 0.0680 - accuracy: 0.9770 - val_loss: 0.5359 - val_accuracy: 0.8980 - 956ms/epoch - 74ms/step
# Epoch 60/80
# 13/13 - 1s - loss: 0.0376 - accuracy: 0.9872 - val_loss: 0.5933 - val_accuracy: 0.8878 - 959ms/epoch - 74ms/step
# Epoch 61/80
# 13/13 - 1s - loss: 0.0562 - accuracy: 0.9770 - val_loss: 0.5390 - val_accuracy: 0.8571 - 952ms/epoch - 73ms/step
# Epoch 62/80
# 13/13 - 1s - loss: 0.0279 - accuracy: 0.9923 - val_loss: 0.6644 - val_accuracy: 0.8980 - 963ms/epoch - 74ms/step
# Epoch 63/80
# 13/13 - 1s - loss: 0.0241 - accuracy: 0.9898 - val_loss: 0.6611 - val_accuracy: 0.8878 - 988ms/epoch - 76ms/step
# Epoch 64/80
# 13/13 - 1s - loss: 0.0252 - accuracy: 0.9898 - val_loss: 0.4817 - val_accuracy: 0.9082 - 968ms/epoch - 74ms/step
# Epoch 65/80
# 13/13 - 1s - loss: 0.0334 - accuracy: 0.9847 - val_loss: 0.7197 - val_accuracy: 0.8878 - 962ms/epoch - 74ms/step
# Epoch 66/80
# 13/13 - 1s - loss: 0.0471 - accuracy: 0.9872 - val_loss: 0.6235 - val_accuracy: 0.8980 - 959ms/epoch - 74ms/step
# Epoch 67/80
# 13/13 - 1s - loss: 0.0352 - accuracy: 0.9898 - val_loss: 0.5778 - val_accuracy: 0.9184 - 962ms/epoch - 74ms/step
# Epoch 68/80
# 13/13 - 1s - loss: 0.0524 - accuracy: 0.9821 - val_loss: 0.7531 - val_accuracy: 0.9082 - 954ms/epoch - 73ms/step
# Epoch 69/80
# 13/13 - 1s - loss: 0.0295 - accuracy: 0.9923 - val_loss: 0.5662 - val_accuracy: 0.9082 - 948ms/epoch - 73ms/step
# Epoch 70/80
# 13/13 - 1s - loss: 0.0148 - accuracy: 0.9949 - val_loss: 0.6724 - val_accuracy: 0.8980 - 960ms/epoch - 74ms/step
# Epoch 71/80
# 13/13 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.6828 - val_accuracy: 0.8878 - 961ms/epoch - 74ms/step
# Epoch 72/80
# 13/13 - 1s - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.7249 - val_accuracy: 0.8980 - 961ms/epoch - 74ms/step
# Epoch 73/80
# 13/13 - 1s - loss: 0.0085 - accuracy: 0.9949 - val_loss: 0.7578 - val_accuracy: 0.9082 - 963ms/epoch - 74ms/step
# Epoch 74/80
# 13/13 - 1s - loss: 0.0121 - accuracy: 0.9949 - val_loss: 0.8466 - val_accuracy: 0.8571 - 969ms/epoch - 75ms/step
# Epoch 75/80
# 13/13 - 1s - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.8410 - val_accuracy: 0.8673 - 955ms/epoch - 73ms/step
# Epoch 76/80
# 13/13 - 1s - loss: 0.0257 - accuracy: 0.9949 - val_loss: 0.7734 - val_accuracy: 0.9082 - 966ms/epoch - 74ms/step
# Epoch 77/80
# 13/13 - 1s - loss: 0.0229 - accuracy: 0.9923 - val_loss: 0.7645 - val_accuracy: 0.9082 - 959ms/epoch - 74ms/step
# Epoch 78/80
# 13/13 - 1s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.9284 - val_accuracy: 0.8571 - 955ms/epoch - 73ms/step
# Epoch 79/80
# 13/13 - 1s - loss: 0.0248 - accuracy: 0.9898 - val_loss: 0.7886 - val_accuracy: 0.8776 - 959ms/epoch - 74ms/step
# Epoch 80/80
# 13/13 - 1s - loss: 0.0238 - accuracy: 0.9949 - val_loss: 0.6452 - val_accuracy: 0.8776 - 954ms/epoch - 73ms/step

# %%
test_loss,test_acc=model.evaluate(X_test,ytest)
print(test_loss)
print(test_acc)
# Out:
# 4/4 [==============================] - 1s 156ms/step - loss: 0.4449 - accuracy: 0.9024
# 0.4449049234390259
# 0.9024389982223511

# %%
train_loss = history.history['loss']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']
xc=range(80)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])
