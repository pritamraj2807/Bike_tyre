# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import os

# %%
img=image.load_img("/content/drive/MyDrive/BASE_DATA_mul/Training/bad/s (264).jpg")
plt.imshow(img)

# %%
img=image.load_img("/content/drive/MyDrive/BASE_DATA_mul/Training/good/z (264).jpg")
plt.imshow(img)

# %%
import glob
Good_img = glob.glob('/content/drive/MyDrive/BASE_DATA_mul/Training/good/*.*')
Bad_img = glob.glob('/content/drive/MyDrive/BASE_DATA_mul/Training/bad/*.*')

# %%
data = []
labels = []

for i in Bad_img:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(0)

# %%
for i in Good_img:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (280,280))
    image=np.array(image)
    data.append(image)
    labels.append(1)

# %%
len(data)
# Out:
# 612

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, ytrain, ytest = train_test_split(data, labels, test_size=0.2,random_state=70)

# %%
len(X_train)
# Out:
# 489

# %%
X_train = np.array(X_train, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)
ytrain = np.array(ytrain, dtype=np.float32)
ytest = np.array(ytest, dtype=np.float32)

# %%
print(ytrain.shape)
# Out:
# (489,)

# %%
print(len(X_train))
print(len(ytrain))
print(len(X_test))
print(len(ytest))

print(X_train.shape)
print(ytrain.shape)
print(X_test.shape)
print(ytest.shape)
# Out:
# 489
# 489
# 123
# 123
# (489, 280, 280, 3)
# (489,)
# (123, 280, 280, 3)
# (123,)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
from keras.utils import np_utils
ytrain = np_utils.to_categorical(ytrain)
ytest = np_utils.to_categorical(ytest)
num_classes = ytest.shape[1]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import RMSprop
from keras.layers.convolutional import Conv2D
from keras.layers import BatchNormalization
from keras.layers.convolutional import MaxPooling2D
from sklearn.model_selection import train_test_split

# %%
def AlexNet_model():

    model = Sequential()
    
    model.add(Conv2D(32, (3, 3), input_shape=(280, 280, 3), activation='relu',padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    
    model.add(Conv2D(32, (3, 3), activation='relu',padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), activation='relu',padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    
    model.add(Conv2D(128, (3, 3), activation='relu',padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(128, (3, 3), activation='relu',padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Dropout(0.5))
    model.add(Flatten())

    
    model.add(Dense(1024, activation='relu'))
    model.add(Dense(512, activation='relu'))
    
    model.add(Dense(num_classes, activation='softmax'))
    
    lrate = 0.01
    epochs=25
    decay = lrate/epochs
    sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=True)
    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
    
    return model

# %%
model = AlexNet_model()
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_65 (Conv2D)          (None, 280, 280, 32)      896
#
#  max_pooling2d_45 (MaxPoolin  (None, 140, 140, 32)     0
#  g2D)
#
#  conv2d_66 (Conv2D)          (None, 140, 140, 32)      9248
#
#  max_pooling2d_46 (MaxPoolin  (None, 70, 70, 32)       0
#  g2D)
#
#  conv2d_67 (Conv2D)          (None, 70, 70, 64)        18496
#
#  max_pooling2d_47 (MaxPoolin  (None, 35, 35, 64)       0
#  g2D)
#
#  conv2d_68 (Conv2D)          (None, 35, 35, 128)       73856
#
#  max_pooling2d_48 (MaxPoolin  (None, 17, 17, 128)      0
#  g2D)
#
#  conv2d_69 (Conv2D)          (None, 17, 17, 128)       147584
#
#  max_pooling2d_49 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  dropout_15 (Dropout)        (None, 8, 8, 128)         0
#
#  flatten_14 (Flatten)        (None, 8192)              0
#
#  dense_39 (Dense)            (None, 1024)              8389632
#
#  dense_40 (Dense)            (None, 512)               524800
#
#  dense_41 (Dense)            (None, 2)                 1026
#
# =================================================================
# Total params: 9,165,538
# Trainable params: 9,165,538
# Non-trainable params: 0
# _________________________________________________________________

# %%
os.chdir("/content/drive/My Drive/2021/")
from keras.callbacks import ModelCheckpoint, CSVLogger
mc = ModelCheckpoint('TyreAlexNetNet.h5', monitor='val_loss', save_best_only=True)
cv = CSVLogger('TyreAlexNetNet.csv',append=True)

# %%
history=model.fit(np.array(X_train), np.array(ytrain), validation_split=(0.2), epochs=80, batch_size=32,verbose=2,callbacks=[cv,mc])
# Out:
# Epoch 1/80
# 13/13 - 3s - loss: 0.6945 - accuracy: 0.4706 - val_loss: 0.6892 - val_accuracy: 0.5306 - 3s/epoch - 247ms/step
# Epoch 2/80
# 13/13 - 1s - loss: 0.6924 - accuracy: 0.5166 - val_loss: 0.6875 - val_accuracy: 0.5306 - 1s/epoch - 105ms/step
# Epoch 3/80
# 13/13 - 1s - loss: 0.6898 - accuracy: 0.5269 - val_loss: 0.6848 - val_accuracy: 0.5612 - 1s/epoch - 108ms/step
# Epoch 4/80
# 13/13 - 1s - loss: 0.6855 - accuracy: 0.6394 - val_loss: 0.6790 - val_accuracy: 0.5306 - 1s/epoch - 101ms/step
# Epoch 5/80
# 13/13 - 1s - loss: 0.6842 - accuracy: 0.5320 - val_loss: 0.6783 - val_accuracy: 0.6327 - 1s/epoch - 97ms/step
# Epoch 6/80
# 13/13 - 1s - loss: 0.6749 - accuracy: 0.6292 - val_loss: 0.6644 - val_accuracy: 0.5510 - 1s/epoch - 97ms/step
# Epoch 7/80
# 13/13 - 1s - loss: 0.6664 - accuracy: 0.6394 - val_loss: 0.6489 - val_accuracy: 0.6633 - 1s/epoch - 94ms/step
# Epoch 8/80
# 13/13 - 1s - loss: 0.6513 - accuracy: 0.6419 - val_loss: 0.7367 - val_accuracy: 0.5612 - 976ms/epoch - 75ms/step
# Epoch 9/80
# 13/13 - 1s - loss: 0.6462 - accuracy: 0.6087 - val_loss: 0.7631 - val_accuracy: 0.5714 - 967ms/epoch - 74ms/step
# Epoch 10/80
# 13/13 - 1s - loss: 0.6845 - accuracy: 0.5806 - val_loss: 0.6244 - val_accuracy: 0.6020 - 1s/epoch - 95ms/step
# Epoch 11/80
# 13/13 - 1s - loss: 0.6244 - accuracy: 0.6650 - val_loss: 0.6024 - val_accuracy: 0.6633 - 1s/epoch - 94ms/step
# Epoch 12/80
# 13/13 - 1s - loss: 0.6120 - accuracy: 0.7008 - val_loss: 0.5745 - val_accuracy: 0.6837 - 1s/epoch - 94ms/step
# Epoch 13/80
# 13/13 - 1s - loss: 0.5868 - accuracy: 0.6931 - val_loss: 0.5886 - val_accuracy: 0.6735 - 976ms/epoch - 75ms/step
# Epoch 14/80
# 13/13 - 1s - loss: 0.5851 - accuracy: 0.7033 - val_loss: 0.7344 - val_accuracy: 0.5306 - 974ms/epoch - 75ms/step
# Epoch 15/80
# 13/13 - 1s - loss: 0.6035 - accuracy: 0.6701 - val_loss: 0.5239 - val_accuracy: 0.7245 - 1s/epoch - 95ms/step
# Epoch 16/80
# 13/13 - 1s - loss: 0.5448 - accuracy: 0.7084 - val_loss: 0.5172 - val_accuracy: 0.7347 - 1s/epoch - 95ms/step
# Epoch 17/80
# 13/13 - 1s - loss: 0.5141 - accuracy: 0.7519 - val_loss: 0.5215 - val_accuracy: 0.7347 - 960ms/epoch - 74ms/step
# Epoch 18/80
# 13/13 - 1s - loss: 0.5011 - accuracy: 0.7570 - val_loss: 0.4943 - val_accuracy: 0.7551 - 1s/epoch - 94ms/step
# Epoch 19/80
# 13/13 - 1s - loss: 0.4688 - accuracy: 0.7852 - val_loss: 0.5140 - val_accuracy: 0.7959 - 960ms/epoch - 74ms/step
# Epoch 20/80
# 13/13 - 1s - loss: 0.4399 - accuracy: 0.8133 - val_loss: 0.5598 - val_accuracy: 0.6633 - 960ms/epoch - 74ms/step
# Epoch 21/80
# 13/13 - 1s - loss: 0.4176 - accuracy: 0.8082 - val_loss: 0.4578 - val_accuracy: 0.7551 - 1s/epoch - 94ms/step
# Epoch 22/80
# 13/13 - 1s - loss: 0.4171 - accuracy: 0.8184 - val_loss: 0.4394 - val_accuracy: 0.7653 - 1s/epoch - 97ms/step
# Epoch 23/80
# 13/13 - 1s - loss: 0.4324 - accuracy: 0.7826 - val_loss: 0.6073 - val_accuracy: 0.7959 - 972ms/epoch - 75ms/step
# Epoch 24/80
# 13/13 - 1s - loss: 0.3579 - accuracy: 0.8670 - val_loss: 1.7305 - val_accuracy: 0.4796 - 973ms/epoch - 75ms/step
# Epoch 25/80
# 13/13 - 1s - loss: 0.7416 - accuracy: 0.6113 - val_loss: 0.6265 - val_accuracy: 0.6939 - 948ms/epoch - 73ms/step
# Epoch 26/80
# 13/13 - 1s - loss: 0.6083 - accuracy: 0.6752 - val_loss: 0.6217 - val_accuracy: 0.6633 - 948ms/epoch - 73ms/step
# Epoch 27/80
# 13/13 - 1s - loss: 0.5791 - accuracy: 0.6675 - val_loss: 0.6410 - val_accuracy: 0.6327 - 946ms/epoch - 73ms/step
# Epoch 28/80
# 13/13 - 1s - loss: 0.5526 - accuracy: 0.7340 - val_loss: 0.7941 - val_accuracy: 0.5204 - 956ms/epoch - 74ms/step
# Epoch 29/80
# 13/13 - 1s - loss: 0.5091 - accuracy: 0.7340 - val_loss: 0.7997 - val_accuracy: 0.5306 - 956ms/epoch - 74ms/step
# Epoch 30/80
# 13/13 - 1s - loss: 0.4921 - accuracy: 0.7775 - val_loss: 0.5339 - val_accuracy: 0.7347 - 965ms/epoch - 74ms/step
# Epoch 31/80
# 13/13 - 1s - loss: 0.4442 - accuracy: 0.7877 - val_loss: 0.4961 - val_accuracy: 0.7041 - 966ms/epoch - 74ms/step
# Epoch 32/80
# 13/13 - 1s - loss: 0.3469 - accuracy: 0.8312 - val_loss: 0.4952 - val_accuracy: 0.7449 - 960ms/epoch - 74ms/step
# Epoch 33/80
# 13/13 - 1s - loss: 0.3437 - accuracy: 0.8363 - val_loss: 0.4256 - val_accuracy: 0.8367 - 1s/epoch - 98ms/step
# Epoch 34/80
# 13/13 - 1s - loss: 0.3036 - accuracy: 0.8619 - val_loss: 0.5348 - val_accuracy: 0.7551 - 968ms/epoch - 74ms/step
# Epoch 35/80
# 13/13 - 1s - loss: 0.2658 - accuracy: 0.8824 - val_loss: 0.4496 - val_accuracy: 0.7755 - 961ms/epoch - 74ms/step
# Epoch 36/80
# 13/13 - 1s - loss: 0.1959 - accuracy: 0.9182 - val_loss: 0.5608 - val_accuracy: 0.7653 - 956ms/epoch - 74ms/step
# Epoch 37/80
# 13/13 - 1s - loss: 0.1945 - accuracy: 0.9233 - val_loss: 0.4227 - val_accuracy: 0.8265 - 1s/epoch - 108ms/step
# Epoch 38/80
# 13/13 - 1s - loss: 0.2066 - accuracy: 0.9284 - val_loss: 0.3828 - val_accuracy: 0.8469 - 1s/epoch - 107ms/step
# Epoch 39/80
# 13/13 - 1s - loss: 0.1568 - accuracy: 0.9412 - val_loss: 0.4438 - val_accuracy: 0.8571 - 1s/epoch - 81ms/step
# Epoch 40/80
# 13/13 - 1s - loss: 0.1317 - accuracy: 0.9540 - val_loss: 0.3389 - val_accuracy: 0.8673 - 1s/epoch - 101ms/step
# Epoch 41/80
# 13/13 - 1s - loss: 0.1048 - accuracy: 0.9642 - val_loss: 0.3139 - val_accuracy: 0.8980 - 1s/epoch - 96ms/step
# Epoch 42/80
# 13/13 - 1s - loss: 0.0996 - accuracy: 0.9719 - val_loss: 0.3094 - val_accuracy: 0.9184 - 1s/epoch - 95ms/step
# Epoch 43/80
# 13/13 - 1s - loss: 0.0905 - accuracy: 0.9744 - val_loss: 0.2768 - val_accuracy: 0.8878 - 1s/epoch - 94ms/step
# Epoch 44/80
# 13/13 - 1s - loss: 0.0792 - accuracy: 0.9693 - val_loss: 0.2993 - val_accuracy: 0.9082 - 955ms/epoch - 73ms/step
# Epoch 45/80
# 13/13 - 1s - loss: 0.0690 - accuracy: 0.9821 - val_loss: 0.2679 - val_accuracy: 0.9286 - 1s/epoch - 93ms/step
# Epoch 46/80
# 13/13 - 1s - loss: 0.0921 - accuracy: 0.9591 - val_loss: 0.3321 - val_accuracy: 0.9082 - 952ms/epoch - 73ms/step
# Epoch 47/80
# 13/13 - 1s - loss: 0.0616 - accuracy: 0.9770 - val_loss: 0.4048 - val_accuracy: 0.9184 - 990ms/epoch - 76ms/step
# Epoch 48/80
# 13/13 - 1s - loss: 0.0640 - accuracy: 0.9770 - val_loss: 0.3240 - val_accuracy: 0.9082 - 949ms/epoch - 73ms/step
# Epoch 49/80
# 13/13 - 1s - loss: 0.0686 - accuracy: 0.9770 - val_loss: 0.2646 - val_accuracy: 0.9388 - 1s/epoch - 94ms/step
# Epoch 50/80
# 13/13 - 1s - loss: 0.0950 - accuracy: 0.9770 - val_loss: 0.2915 - val_accuracy: 0.9082 - 955ms/epoch - 73ms/step
# Epoch 51/80
# 13/13 - 1s - loss: 0.0947 - accuracy: 0.9668 - val_loss: 0.2587 - val_accuracy: 0.9184 - 1s/epoch - 94ms/step
# Epoch 52/80
# 13/13 - 1s - loss: 0.0388 - accuracy: 0.9898 - val_loss: 0.2577 - val_accuracy: 0.9184 - 1s/epoch - 95ms/step
# Epoch 53/80
# 13/13 - 1s - loss: 0.0263 - accuracy: 0.9923 - val_loss: 0.2541 - val_accuracy: 0.9388 - 1s/epoch - 95ms/step
# Epoch 54/80
# 13/13 - 1s - loss: 0.0435 - accuracy: 0.9898 - val_loss: 0.4175 - val_accuracy: 0.8980 - 969ms/epoch - 75ms/step
# Epoch 55/80
# 13/13 - 1s - loss: 0.1121 - accuracy: 0.9616 - val_loss: 0.5379 - val_accuracy: 0.8469 - 954ms/epoch - 73ms/step
# Epoch 56/80
# 13/13 - 1s - loss: 0.0472 - accuracy: 0.9821 - val_loss: 0.4058 - val_accuracy: 0.8776 - 952ms/epoch - 73ms/step
# Epoch 57/80
# 13/13 - 1s - loss: 0.1099 - accuracy: 0.9540 - val_loss: 0.3644 - val_accuracy: 0.8980 - 968ms/epoch - 74ms/step
# Epoch 58/80
# 13/13 - 1s - loss: 0.0634 - accuracy: 0.9821 - val_loss: 0.2979 - val_accuracy: 0.8878 - 954ms/epoch - 73ms/step
# Epoch 59/80
# 13/13 - 1s - loss: 0.0340 - accuracy: 0.9821 - val_loss: 0.3384 - val_accuracy: 0.9286 - 977ms/epoch - 75ms/step
# Epoch 60/80
# 13/13 - 1s - loss: 0.0311 - accuracy: 0.9898 - val_loss: 0.5410 - val_accuracy: 0.8980 - 988ms/epoch - 76ms/step
# Epoch 61/80
# 13/13 - 1s - loss: 0.0386 - accuracy: 0.9847 - val_loss: 0.4040 - val_accuracy: 0.9184 - 957ms/epoch - 74ms/step
# Epoch 62/80
# 13/13 - 1s - loss: 0.0233 - accuracy: 0.9898 - val_loss: 0.3901 - val_accuracy: 0.9082 - 965ms/epoch - 74ms/step
# Epoch 63/80
# 13/13 - 1s - loss: 0.0271 - accuracy: 0.9923 - val_loss: 0.4266 - val_accuracy: 0.9184 - 978ms/epoch - 75ms/step
# Epoch 64/80
# 13/13 - 1s - loss: 0.0247 - accuracy: 0.9949 - val_loss: 0.5334 - val_accuracy: 0.8980 - 953ms/epoch - 73ms/step
# Epoch 65/80
# 13/13 - 1s - loss: 0.0344 - accuracy: 0.9821 - val_loss: 0.2832 - val_accuracy: 0.9490 - 964ms/epoch - 74ms/step
# Epoch 66/80
# 13/13 - 1s - loss: 0.0719 - accuracy: 0.9744 - val_loss: 0.4924 - val_accuracy: 0.8980 - 963ms/epoch - 74ms/step
# Epoch 67/80
# 13/13 - 1s - loss: 0.0473 - accuracy: 0.9821 - val_loss: 0.2911 - val_accuracy: 0.9388 - 955ms/epoch - 73ms/step
# Epoch 68/80
# 13/13 - 1s - loss: 0.0266 - accuracy: 0.9949 - val_loss: 0.2971 - val_accuracy: 0.9388 - 988ms/epoch - 76ms/step
# Epoch 69/80
# 13/13 - 1s - loss: 0.0322 - accuracy: 0.9923 - val_loss: 0.3756 - val_accuracy: 0.9388 - 968ms/epoch - 74ms/step
# Epoch 70/80
# 13/13 - 1s - loss: 0.0229 - accuracy: 0.9949 - val_loss: 0.2806 - val_accuracy: 0.9490 - 962ms/epoch - 74ms/step
# Epoch 71/80
# 13/13 - 1s - loss: 0.0152 - accuracy: 0.9923 - val_loss: 0.2994 - val_accuracy: 0.9388 - 959ms/epoch - 74ms/step
# Epoch 72/80
# 13/13 - 1s - loss: 0.0173 - accuracy: 0.9974 - val_loss: 0.4362 - val_accuracy: 0.9286 - 965ms/epoch - 74ms/step
# Epoch 73/80
# 13/13 - 1s - loss: 0.0280 - accuracy: 0.9949 - val_loss: 0.4426 - val_accuracy: 0.9184 - 972ms/epoch - 75ms/step
# Epoch 74/80
# 13/13 - 1s - loss: 0.0136 - accuracy: 0.9949 - val_loss: 0.3169 - val_accuracy: 0.9184 - 956ms/epoch - 74ms/step
# Epoch 75/80
# 13/13 - 1s - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.3488 - val_accuracy: 0.9082 - 965ms/epoch - 74ms/step
# Epoch 76/80
# 13/13 - 1s - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.4291 - val_accuracy: 0.9184 - 957ms/epoch - 74ms/step
# Epoch 77/80
# 13/13 - 1s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.6524 - val_accuracy: 0.9184 - 969ms/epoch - 75ms/step
# Epoch 78/80
# 13/13 - 1s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.3894 - val_accuracy: 0.9184 - 983ms/epoch - 76ms/step
# Epoch 79/80
# 13/13 - 1s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.3650 - val_accuracy: 0.9388 - 961ms/epoch - 74ms/step
# Epoch 80/80
# 13/13 - 1s - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.3676 - val_accuracy: 0.9388 - 990ms/epoch - 76ms/step

# %%
test_loss,test_acc=model.evaluate(X_test,ytest)
print(test_loss)
print(test_acc)
# Out:
# 4/4 [==============================] - 0s 36ms/step - loss: 0.7120 - accuracy: 0.8862
# 0.7119725942611694
# 0.8861788511276245

# %%
train_loss = history.history['loss']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']
xc=range(80)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])
